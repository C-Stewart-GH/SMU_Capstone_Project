# %%
import json
import os
import numpy as np
from collections import Counter
from datetime import datetime as dt
from datetime import timedelta
import copy
import pickle
import bz2
import pandas as pd
from scipy.stats import rankdata  
import pickle
import bz2

# %%
#Load raw rankings (in JSON format)
aau_path = os.fsencode("/Users/cameron/Documents/SMU_DS/Capstone/SMU_Capstone_Project/Historical_Rankings.txt/Ranking_AAU.txt")
bvne_path = os.fsencode("/Users/cameron/Documents/SMU_DS/Capstone/SMU_Capstone_Project/Historical_Rankings.txt/Ranking_BVNE.txt")
p1440_path = os.fsencode("/Users/cameron/Documents/SMU_DS/Capstone/SMU_Capstone_Project/Historical_Rankings.txt/Ranking_p1440.txt")

file = open(aau_path)
aau_raw_rankings=json.load(file)
file.close()

file = open(bvne_path)
bvne_raw_rankings=json.load(file)
file.close()

file = open(p1440_path)
p1440_raw_rankings=json.load(file)
file.close()

# %%
#Example of single ranking set on specific date
aau_raw_rankings[0]
# Out:
# {'AsOf': '2019-01-07T00:00:00',
#  'Players': [{'PlayerProfileId': 123, 'Points': 1119.0},
#   {'PlayerProfileId': 124, 'Points': 618.0},
#   {'PlayerProfileId': 125, 'Points': 1494.7},
#   {'PlayerProfileId': 127, 'Points': 490.0},
#   {'PlayerProfileId': 128, 'Points': 120.0},
#   {'PlayerProfileId': 129, 'Points': 765.0},
#   {'PlayerProfileId': 130, 'Points': 255.0},
#   {'PlayerProfileId': 131, 'Points': 1570.0},
#   {'PlayerProfileId': 132, 'Points': 1785.0},
#   {'PlayerProfileId': 133, 'Points': 340.5},
#   {'PlayerProfileId': 134, 'Points': 150.0},
#   {'PlayerProfileId': 135, 'Points': 30.0},
#   {'PlayerProfileId': 136, 'Points': 30.0},
#   {'PlayerProfileId': 137, 'Points': 3558.1},
#   {'PlayerProfileId': 139, 'Points': 5.0},
#   {'PlayerProfileId': 140, 'Points': 5.0},
#   {'PlayerProfileId': 141, 'Points': 1564.0},
#   {'PlayerProfileId': 142, 'Points': 1755.0},
#   {'PlayerProfileId': 143, 'Points': 1368.0},
#   {'PlayerProfileId': 144, 'Points': 1320.0},
#   {'PlayerProfileId': 146, 'Points': 475.0},
#   {'PlayerProfileId': 147, 'Points': 396.0},
#   {'PlayerProfileId': 148, 'Points': 1403.0},
#   {'PlayerProfileId': 149, 'Points': 2085.0},
#   {'PlayerProfileId': 150, 'Points': 3172.0},
#   {'PlayerProfileId': 151, 'Points': 1915.0},
#   {'PlayerProfileId': 152, 'Points': 66.0},
#   {'PlayerProfileId': 155, 'Points': 2917.0},
#   {'PlayerProfileId': 156, 'Points': 1054.0},
#   {'PlayerProfileId': 157, 'Points': 264.0},
#   {'PlayerProfileId': 158, 'Points': 2184.0},
#   {'PlayerProfileId': 159, 'Points': 66.0},
#   {'PlayerProfileId': 160, 'Points': 66.0},
#   {'PlayerProfileId': 161, 'Points': 81.0},
#   {'PlayerProfileId': 162, 'Points': 66.0},
#   {'PlayerProfileId': 346, 'Points': 976.5},
#   {'PlayerProfileId': 347, 'Points': 380.0},
#   {'PlayerProfileId': 349, 'Points': 1829.0},
#   {'PlayerProfileId': 350, 'Points': 101.5},
#   {'PlayerProfileId': 351, 'Points': 745.5},
#   {'PlayerProfileId': 352, 'Points': 115.0},
#   {'PlayerProfileId': 353, 'Points': 795.0},
#   {'PlayerProfileId': 354, 'Points': 704.0},
#   {'PlayerProfileId': 355, 'Points': 154.0},
#   {'PlayerProfileId': 357, 'Points': 272.0},
#   {'PlayerProfileId': 358, 'Points': 1604.0},
#   {'PlayerProfileId': 359, 'Points': 766.0},
#   {'PlayerProfileId': 361, 'Points': 1854.0},
#   {'PlayerProfileId': 362, 'Points': 1503.0},
#   {'PlayerProfileId': 363, 'Points': 1259.0},
#   {'PlayerProfileId': 364, 'Points': 77.0},
#   {'PlayerProfileId': 366, 'Points': 876.0},
#   {'PlayerProfileId': 367, 'Points': 1087.0},
#   {'PlayerProfileId': 369, 'Points': 504.0},
#   {'PlayerProfileId': 370, 'Points': 38.0},
#   {'PlayerProfileId': 371, 'Points': 152.0},
#   {'PlayerProfileId': 372, 'Points': 282.0},
#   {'PlayerProfileId': 373, 'Points': 203.0},
#   {'PlayerProfileId': 374, 'Points': 968.0},
#   {'PlayerProfileId': 377, 'Points': 254.0},
#   {'PlayerProfileId': 378, 'Points': 602.0},
#   {'PlayerProfileId': 379, 'Points': 605.0},
#   {'PlayerProfileId': 380, 'Points': 5.0},
#   {'PlayerProfileId': 381, 'Points': 1077.0},
#   {'PlayerProfileId': 383, 'Points': 955.0},
#   {'PlayerProfileId': 384, 'Points': 1873.5},
#   {'PlayerProfileId': 385, 'Points': 54.50000000000001},
#   {'PlayerProfileId': 386, 'Points': 219.50000000000003},
#   {'PlayerProfileId': 387, 'Points': 901.5},
#   {'PlayerProfileId': 388, 'Points': 1215.0},
#   {'PlayerProfileId': 389, 'Points': 675.0},
#   {'PlayerProfileId': 390, 'Points': 1870.5},
#   {'PlayerProfileId': 392, 'Points': 685.0},
#   {'PlayerProfileId': 393, 'Points': 3075.5},
#   {'PlayerProfileId': 394, 'Points': 925.0},
#   {'PlayerProfileId': 395, 'Points': 1811.5},
#   {'PlayerProfileId': 396, 'Points': 1771.5},
#   {'PlayerProfileId': 397, 'Points': 955.5},
#   {'PlayerProfileId': 398, 'Points': 3054.0},
#   {'PlayerProfileId': 399, 'Points': 2365.1},
#   {'PlayerProfileId': 400, 'Points': 1978.0},
#   {'PlayerProfileId': 401, 'Points': 776.9000000000001},
#   {'PlayerProfileId': 402, 'Points': 125.50000000000001},
#   {'PlayerProfileId': 403, 'Points': 1057.5},
#   {'PlayerProfileId': 404, 'Points': 1353.0},
#   {'PlayerProfileId': 405, 'Points': 915.0},
#   {'PlayerProfileId': 406, 'Points': 1078.0},
#   {'PlayerProfileId': 408, 'Points': 2128.0},
#   {'PlayerProfileId': 409, 'Points': 1496.0},
#   {'PlayerProfileId': 410, 'Points': 861.0},
#   {'PlayerProfileId': 411, 'Points': 682.0},
#   {'PlayerProfileId': 412, 'Points': 3067.0},
#   {'PlayerProfileId': 413, 'Points': 1050.0},
#   {'PlayerProfileId': 414, 'Points': 264.0},
#   {'PlayerProfileId': 415, 'Points': 330.0},
#   {'PlayerProfileId': 416, 'Points': 1208.0},
#   {'PlayerProfileId': 417, 'Points': 781.0},
#   {'PlayerProfileId': 418, 'Points': 1212.0},
#   {'PlayerProfileId': 419, 'Points': 613.0},
#   {'PlayerProfileId': 420, 'Points': 387.5},
#   {'PlayerProfileId': 422, 'Points': 2028.0},
#   {'PlayerProfileId': 423, 'Points': 1948.0000000000002},
#   {'PlayerProfileId': 424, 'Points': 4609.5},
#   {'PlayerProfileId': 425, 'Points': 327.0},
#   {'PlayerProfileId': 426, 'Points': 327.0},
#   {'PlayerProfileId': 427, 'Points': 66.0},
#   {'PlayerProfileId': 428, 'Points': 66.0},
#   {'PlayerProfileId': 430, 'Points': 529.0},
#   {'PlayerProfileId': 432, 'Points': 942.0},
#   {'PlayerProfileId': 433, 'Points': 1067.0},
#   {'PlayerProfileId': 446, 'Points': 100.0},
#   {'PlayerProfileId': 447, 'Points': 100.0},
#   {'PlayerProfileId': 448, 'Points': 150.0},
#   {'PlayerProfileId': 449, 'Points': 310.0},
#   {'PlayerProfileId': 450, 'Points': 100.0},
#   {'PlayerProfileId': 451, 'Points': 100.0},
#   {'PlayerProfileId': 452, 'Points': 520.0},
#   {'PlayerProfileId': 453, 'Points': 120.0},
#   {'PlayerProfileId': 454, 'Points': 760.0},
#   {'PlayerProfileId': 455, 'Points': 360.0},
#   {'PlayerProfileId': 456, 'Points': 600.0},
#   {'PlayerProfileId': 457, 'Points': 330.0},
#   {'PlayerProfileId': 458, 'Points': 450.0},
#   {'PlayerProfileId': 459, 'Points': 270.0},
#   {'PlayerProfileId': 460, 'Points': 150.0},
#   {'PlayerProfileId': 461, 'Points': 570.0},
#   {'PlayerProfileId': 462, 'Points': 150.0},
#   {'PlayerProfileId': 463, 'Points': 225.0},
#   {'PlayerProfileId': 464, 'Points': 225.0},
#   {'PlayerProfileId': 465, 'Points': 300.0},
#   {'PlayerProfileId': 466, 'Points': 300.0},
#   {'PlayerProfileId': 467, 'Points': 150.0},
#   {'PlayerProfileId': 468, 'Points': 150.0},
#   {'PlayerProfileId': 469, 'Points': 352.0},
#   {'PlayerProfileId': 470, 'Points': 409.0},
#   {'PlayerProfileId': 471, 'Points': 84.0},
#   {'PlayerProfileId': 472, 'Points': 84.0},
#   {'PlayerProfileId': 473, 'Points': 2690.5},
#   {'PlayerProfileId': 474, 'Points': 2300.0},
#   {'PlayerProfileId': 475, 'Points': 747.0},
#   {'PlayerProfileId': 476, 'Points': 821.0},
#   {'PlayerProfileId': 477, 'Points': 744.0},
#   {'PlayerProfileId': 478, 'Points': 138.0},
#   {'PlayerProfileId': 479, 'Points': 89.0},
#   {'PlayerProfileId': 480, 'Points': 468.0},
#   {'PlayerProfileId': 481, 'Points': 632.0},
#   {'PlayerProfileId': 483, 'Points': 743.0},
#   {'PlayerProfileId': 484, 'Points': 638.0},
#   {'PlayerProfileId': 487, 'Points': 84.0},
#   {'PlayerProfileId': 488, 'Points': 154.0},
#   {'PlayerProfileId': 489, 'Points': 601.0},
#   {'PlayerProfileId': 490, 'Points': 84.0},
#   {'PlayerProfileId': 491, 'Points': 84.0},
#   {'PlayerProfileId': 492, 'Points': 327.0},
#   {'PlayerProfileId': 493, 'Points': 507.0},
#   {'PlayerProfileId': 494, 'Points': 2788.8999999999996},
#   {'PlayerProfileId': 496, 'Points': 1272.0},
#   {'PlayerProfileId': 497, 'Points': 89.0},
#   {'PlayerProfileId': 500, 'Points': 84.0},
#   {'PlayerProfileId': 501, 'Points': 1782.0},
#   {'PlayerProfileId': 502, 'Points': 1594.5},
#   {'PlayerProfileId': 503, 'Points': 454.50000000000006},
#   {'PlayerProfileId': 504, 'Points': 115.50000000000001},
#   {'PlayerProfileId': 505, 'Points': 115.50000000000001},
#   {'PlayerProfileId': 506, 'Points': 410.5},
#   {'PlayerProfileId': 507, 'Points': 115.50000000000001},
#   {'PlayerProfileId': 508, 'Points': 1003.5},
#   {'PlayerProfileId': 509, 'Points': 450.0},
#   {'PlayerProfileId': 510, 'Points': 115.50000000000001},
#   {'PlayerProfileId': 511, 'Points': 115.50000000000001},
#   {'PlayerProfileId': 512, 'Points': 115.50000000000001},
#   {'PlayerProfileId': 513, 'Points': 115.50000000000001},
#   {'PlayerProfileId': 514, 'Points': 115.50000000000001},
#   {'PlayerProfileId': 515, 'Points': 1305.5},
#   {'PlayerProfileId': 516, 'Points': 1363.5},
#   {'PlayerProfileId': 517, 'Points': 2074.5},
#   {'PlayerProfileId': 518, 'Points': 1010.5},
#   {'PlayerProfileId': 519, 'Points': 508.0},
#   {'PlayerProfileId': 520, 'Points': 115.50000000000001},
#   {'PlayerProfileId': 521, 'Points': 115.50000000000001},
#   {'PlayerProfileId': 523, 'Points': 346.50000000000006},
#   {'PlayerProfileId': 526, 'Points': 1947.0},
#   {'PlayerProfileId': 529, 'Points': 168.0},
#   {'PlayerProfileId': 530, 'Points': 336.0},
#   {'PlayerProfileId': 531, 'Points': 1758.0},
#   {'PlayerProfileId': 533, 'Points': 1182.0},
#   {'PlayerProfileId': 534, 'Points': 308.0},
#   {'PlayerProfileId': 535, 'Points': 168.0},
#   {'PlayerProfileId': 536, 'Points': 168.0},
#   {'PlayerProfileId': 538, 'Points': 1248.5},
#   {'PlayerProfileId': 539, 'Points': 828.0},
#   {'PlayerProfileId': 540, 'Points': 606.0},
#   {'PlayerProfileId': 543, 'Points': 168.0},
#   {'PlayerProfileId': 544, 'Points': 168.0},
#   {'PlayerProfileId': 545, 'Points': 168.0},
#   {'PlayerProfileId': 546, 'Points': 3511.0},
#   {'PlayerProfileId': 547, 'Points': 1815.5},
#   {'PlayerProfileId': 552, 'Points': 2864.0},
#   {'PlayerProfileId': 553, 'Points': 1642.0},
#   {'PlayerProfileId': 555, 'Points': 908.0},
#   {'PlayerProfileId': 556, 'Points': 409.0},
#   {'PlayerProfileId': 557, 'Points': 1142.0},
#   {'PlayerProfileId': 558, 'Points': 1076.0},
#   {'PlayerProfileId': 559, 'Points': 1441.0},
#   {'PlayerProfileId': 560, 'Points': 168.0},
#   {'PlayerProfileId': 561, 'Points': 696.0},
#   {'PlayerProfileId': 562, 'Points': 322.0},
#   {'PlayerProfileId': 564, 'Points': 1698.0},
#   {'PlayerProfileId': 565, 'Points': 1280.0},
#   {'PlayerProfileId': 567, 'Points': 83.0},
#   {'PlayerProfileId': 568, 'Points': 118.0},
#   {'PlayerProfileId': 569, 'Points': 198.0},
#   {'PlayerProfileId': 570, 'Points': 195.0},
#   {'PlayerProfileId': 572, 'Points': 160.0},
#   {'PlayerProfileId': 574, 'Points': 342.0},
#   {'PlayerProfileId': 575, 'Points': 120.0},
#   {'PlayerProfileId': 576, 'Points': 120.0},
#   {'PlayerProfileId': 577, 'Points': 687.0},
#   {'PlayerProfileId': 578, 'Points': 699.5},
#   {'PlayerProfileId': 579, 'Points': 120.0},
#   {'PlayerProfileId': 580, 'Points': 506.0},
#   {'PlayerProfileId': 581, 'Points': 407.0},
#   {'PlayerProfileId': 582, 'Points': 120.0},
#   {'PlayerProfileId': 583, 'Points': 530.5},
#   {'PlayerProfileId': 586, 'Points': 1864.0},
#   {'PlayerProfileId': 588, 'Points': 1085.0},
#   {'PlayerProfileId': 589, 'Points': 892.0},
#   {'PlayerProfileId': 590, 'Points': 120.50000000000001},
#   {'PlayerProfileId': 591, 'Points': 120.50000000000001},
#   {'PlayerProfileId': 592, 'Points': 1217.5},
#   {'PlayerProfileId': 593, 'Points': 1321.6},
#   {'PlayerProfileId': 594, 'Points': 5.0},
#   {'PlayerProfileId': 595, 'Points': 5.0},
#   {'PlayerProfileId': 596, 'Points': 110.0},
#   {'PlayerProfileId': 597, 'Points': 5.0},
#   {'PlayerProfileId': 598, 'Points': 231.00000000000003},
#   {'PlayerProfileId': 599, 'Points': 1426.0},
#   {'PlayerProfileId': 600, 'Points': 115.50000000000001},
#   {'PlayerProfileId': 601, 'Points': 115.50000000000001},
#   {'PlayerProfileId': 602, 'Points': 154.5},
#   {'PlayerProfileId': 603, 'Points': 99.00000000000001},
#   {'PlayerProfileId': 604, 'Points': 498.50000000000006},
#   {'PlayerProfileId': 605, 'Points': 115.50000000000001},
#   {'PlayerProfileId': 606, 'Points': 10.0},
#   {'PlayerProfileId': 607, 'Points': 2930.0},
#   {'PlayerProfileId': 608, 'Points': 66.0},
#   {'PlayerProfileId': 609, 'Points': 1168.0},
#   {'PlayerProfileId': 611, 'Points': 335.0},
#   {'PlayerProfileId': 612, 'Points': 622.0},
#   {'PlayerProfileId': 613, 'Points': 269.0},
#   {'PlayerProfileId': 614, 'Points': 55.0},
#   {'PlayerProfileId': 615, 'Points': 383.5},
#   {'PlayerProfileId': 616, 'Points': 70.0},
#   {'PlayerProfileId': 617, 'Points': 180.0},
#   {'PlayerProfileId': 618, 'Points': 549.5},
#   {'PlayerProfileId': 622, 'Points': 320.0},
#   {'PlayerProfileId': 625, 'Points': 336.0},
#   {'PlayerProfileId': 627, 'Points': 769.5},
#   {'PlayerProfileId': 628, 'Points': 255.0},
#   {'PlayerProfileId': 629, 'Points': 155.0},
#   {'PlayerProfileId': 630, 'Points': 300.0},
#   {'PlayerProfileId': 631, 'Points': 349.5},
#   {'PlayerProfileId': 632, 'Points': 2474.0},
#   {'PlayerProfileId': 636, 'Points': 2159.0},
#   {'PlayerProfileId': 641, 'Points': 170.0},
#   {'PlayerProfileId': 642, 'Points': 184.0},
#   {'PlayerProfileId': 643, 'Points': 563.0},
#   {'PlayerProfileId': 647, 'Points': 15.0},
#   {'PlayerProfileId': 649, 'Points': 777.0},
#   {'PlayerProfileId': 650, 'Points': 777.0},
#   {'PlayerProfileId': 653, 'Points': 144.0},
#   {'PlayerProfileId': 654, 'Points': 144.0},
#   {'PlayerProfileId': 655, 'Points': 599.0},
#   {'PlayerProfileId': 657, 'Points': 310.0},
#   {'PlayerProfileId': 658, 'Points': 150.0},
#   {'PlayerProfileId': 662, 'Points': 664.0},
#   {'PlayerProfileId': 663, 'Points': 520.0},
#   {'PlayerProfileId': 664, 'Points': 340.0},
#   {'PlayerProfileId': 668, 'Points': 564.0},
#   {'PlayerProfileId': 670, 'Points': 120.0},
#   {'PlayerProfileId': 672, 'Points': 172.0},
#   {'PlayerProfileId': 673, 'Points': 121.5},
#   {'PlayerProfileId': 674, 'Points': 5.0},
#   {'PlayerProfileId': 680, 'Points': 5.0},
#   {'PlayerProfileId': 681, 'Points': 105.0},
#   {'PlayerProfileId': 682, 'Points': 15.0},
#   {'PlayerProfileId': 684, 'Points': 230.0},
#   {'PlayerProfileId': 685, 'Points': 1015.0},
#   {'PlayerProfileId': 688, 'Points': 415.0},
#   {'PlayerProfileId': 689, 'Points': 445.5},
#   {'PlayerProfileId': 698, 'Points': 901.0},
#   {'PlayerProfileId': 699, 'Points': 771.0},
#   {'PlayerProfileId': 700, 'Points': 38.0},
#   {'PlayerProfileId': 703, 'Points': 684.0},
#   {'PlayerProfileId': 704, 'Points': 229.0},
#   {'PlayerProfileId': 705, 'Points': 197.0},
#   {'PlayerProfileId': 706, 'Points': 1001.0},
#   {'PlayerProfileId': 707, 'Points': 5.0},
#   {'PlayerProfileId': 708, 'Points': 894.7},
#   {'PlayerProfileId': 711, 'Points': 1790.5},
#   {'PlayerProfileId': 712, 'Points': 308.0},
#   {'PlayerProfileId': 714, 'Points': 65.0},
#   {'PlayerProfileId': 715, 'Points': 154.0},
#   {'PlayerProfileId': 716, 'Points': 159.0},
#   {'PlayerProfileId': 717, 'Points': 640.0},
#   {'PlayerProfileId': 718, 'Points': 1715.0},
#   {'PlayerProfileId': 720, 'Points': 154.0},
#   {'PlayerProfileId': 721, 'Points': 976.0},
#   {'PlayerProfileId': 722, 'Points': 258.0},
#   {'PlayerProfileId': 723, 'Points': 159.0},
#   {'PlayerProfileId': 724, 'Points': 159.0},
#   {'PlayerProfileId': 725, 'Points': 120.0},
#   {'PlayerProfileId': 729, 'Points': 417.0},
#   {'PlayerProfileId': 730, 'Points': 222.0},
#   {'PlayerProfileId': 731, 'Points': 33.0},
#   {'PlayerProfileId': 732, 'Points': 33.0},
#   {'PlayerProfileId': 733, 'Points': 67.0},
#   {'PlayerProfileId': 734, 'Points': 5.0},
#   {'PlayerProfileId': 735, 'Points': 5.0},
#   {'PlayerProfileId': 737, 'Points': 22.0},
#   {'PlayerProfileId': 738, 'Points': 22.0},
#   {'PlayerProfileId': 739, 'Points': 22.0},
#   {'PlayerProfileId': 740, 'Points': 673.5},
#   {'PlayerProfileId': 741, 'Points': 158.5},
#   {'PlayerProfileId': 742, 'Points': 158.5},
#   {'PlayerProfileId': 743, 'Points': 68.0},
#   {'PlayerProfileId': 744, 'Points': 5.0},
#   {'PlayerProfileId': 745, 'Points': 99.0},
#   {'PlayerProfileId': 746, 'Points': 501.0},
#   {'PlayerProfileId': 747, 'Points': 1019.0},
#   {'PlayerProfileId': 749, 'Points': 2089.5},
#   {'PlayerProfileId': 750, 'Points': 281.5},
#   {'PlayerProfileId': 751, 'Points': 382.5},
#   {'PlayerProfileId': 752, 'Points': 33.0},
#   {'PlayerProfileId': 755, 'Points': 1896.5},
#   {'PlayerProfileId': 756, 'Points': 22.0},
#   {'PlayerProfileId': 757, 'Points': 33.0},
#   {'PlayerProfileId': 758, 'Points': 838.5},
#   {'PlayerProfileId': 759, 'Points': 1281.5},
#   {'PlayerProfileId': 761, 'Points': 33.0},
#   {'PlayerProfileId': 762, 'Points': 33.0},
#   {'PlayerProfileId': 763, 'Points': 1160.0},
#   {'PlayerProfileId': 764, 'Points': 51.0},
#   {'PlayerProfileId': 765, 'Points': 118.0},
#   {'PlayerProfileId': 767, 'Points': 5.0},
#   {'PlayerProfileId': 768, 'Points': 145.0},
#   {'PlayerProfileId': 769, 'Points': 484.0},
#   {'PlayerProfileId': 770, 'Points': 381.0},
#   {'PlayerProfileId': 771, 'Points': 5.0},
#   {'PlayerProfileId': 772, 'Points': 990.0},
#   {'PlayerProfileId': 773, 'Points': 630.0},
#   {'PlayerProfileId': 778, 'Points': 2939.5},
#   {'PlayerProfileId': 780, 'Points': 820.5},
#   {'PlayerProfileId': 781, 'Points': 845.0},
#   {'PlayerProfileId': 782, 'Points': 621.0},
#   {'PlayerProfileId': 784, 'Points': 219.0},
#   {'PlayerProfileId': 786, 'Points': 434.5},
#   {'PlayerProfileId': 788, 'Points': 812.7},
#   {'PlayerProfileId': 789, 'Points': 701.7},
#   {'PlayerProfileId': 792, 'Points': 1994.5},
#   {'PlayerProfileId': 794, 'Points': 402.0},
#   {'PlayerProfileId': 797, 'Points': 38.5},
#   {'PlayerProfileId': 809, 'Points': 70.0},
#   {'PlayerProfileId': 812, 'Points': 162.0},
#   {'PlayerProfileId': 813, 'Points': 70.0},
#   {'PlayerProfileId': 815, 'Points': 465.0},
#   {'PlayerProfileId': 816, 'Points': 330.0},
#   {'PlayerProfileId': 817, 'Points': 605.0},
#   {'PlayerProfileId': 825, 'Points': 5.0},
#   {'PlayerProfileId': 837, 'Points': 790.0},
#   {'PlayerProfileId': 838, 'Points': 15.0},
#   {'PlayerProfileId': 853, 'Points': 15.0},
#   {'PlayerProfileId': 857, 'Points': 559.6},
#   {'PlayerProfileId': 861, 'Points': 395.0},
#   {'PlayerProfileId': 863, 'Points': 69.0},
#   {'PlayerProfileId': 864, 'Points': 54.0},
#   {'PlayerProfileId': 865, 'Points': 156.0},
#   {'PlayerProfileId': 867, 'Points': 293.70000000000005},
#   {'PlayerProfileId': 869, 'Points': 864.0},
#   {'PlayerProfileId': 870, 'Points': 1043.5},
#   {'PlayerProfileId': 872, 'Points': 156.0},
#   {'PlayerProfileId': 873, 'Points': 246.0},
#   {'PlayerProfileId': 878, 'Points': 744.0},
#   {'PlayerProfileId': 889, 'Points': 510.0},
#   {'PlayerProfileId': 891, 'Points': 930.5},
#   {'PlayerProfileId': 893, 'Points': 1430.0},
#   {'PlayerProfileId': 894, 'Points': 1430.0},
#   {'PlayerProfileId': 895, 'Points': 138.0},
#   {'PlayerProfileId': 896, 'Points': 102.0},
#   {'PlayerProfileId': 898, 'Points': 155.0},
#   {'PlayerProfileId': 899, 'Points': 457.0},
#   {'PlayerProfileId': 904, 'Points': 154.0},
#   {'PlayerProfileId': 905, 'Points': 720.0},
#   {'PlayerProfileId': 911, 'Points': 380.0},
#   {'PlayerProfileId': 915, 'Points': 1173.0},
#   {'PlayerProfileId': 919, 'Points': 337.0},
#   {'PlayerProfileId': 920, 'Points': 105.0},
#   {'PlayerProfileId': 922, 'Points': 1075.0},
#   {'PlayerProfileId': 927, 'Points': 722.0},
#   {'PlayerProfileId': 928, 'Points': 390.0},
#   {'PlayerProfileId': 929, 'Points': 77.0},
#   {'PlayerProfileId': 930, 'Points': 818.0},
#   {'PlayerProfileId': 931, 'Points': 484.0},
#   {'PlayerProfileId': 932, 'Points': 5.0},
#   {'PlayerProfileId': 933, 'Points': 5.0},
#   {'PlayerProfileId': 934, 'Points': 66.0},
#   {'PlayerProfileId': 935, 'Points': 66.0},
#   {'PlayerProfileId': 936, 'Points': 1149.0},
#   {'PlayerProfileId': 937, 'Points': 1261.0},
#   {'PlayerProfileId': 938, 'Points': 145.20000000000002},
#   {'PlayerProfileId': 939, 'Points': 198.0},
#   {'PlayerProfileId': 940, 'Points': 198.0},
#   {'PlayerProfileId': 941, 'Points': 698.0},
#   {'PlayerProfileId': 942, 'Points': 492.0},
#   {'PlayerProfileId': 943, 'Points': 189.5},
#   {'PlayerProfileId': 944, 'Points': 189.5},
#   {'PlayerProfileId': 945, 'Points': 1230.5},
#   {'PlayerProfileId': 946, 'Points': 671.9000000000001},
#   {'PlayerProfileId': 947, 'Points': 787.4000000000001},
#   {'PlayerProfileId': 948, 'Points': 264.0},
#   {'PlayerProfileId': 949, 'Points': 564.0},
#   {'PlayerProfileId': 950, 'Points': 49.50000000000001},
#   {'PlayerProfileId': 954, 'Points': 434.0},
#   {'PlayerProfileId': 955, 'Points': 220.0},
#   {'PlayerProfileId': 956, 'Points': 193.5},
#   {'PlayerProfileId': 957, 'Points': 333.5},
#   {'PlayerProfileId': 958, 'Points': 20.0},
#   {'PlayerProfileId': 959, 'Points': 5.0},
#   {'PlayerProfileId': 960, 'Points': 365.0},
#   {'PlayerProfileId': 961, 'Points': 365.0},
#   {'PlayerProfileId': 962, 'Points': 405.0},
#   {'PlayerProfileId': 966, 'Points': 220.0},
#   {'PlayerProfileId': 969, 'Points': 1464.0},
#   {'PlayerProfileId': 970, 'Points': 770.0},
#   {'PlayerProfileId': 971, 'Points': 502.0},
#   {'PlayerProfileId': 972, 'Points': 132.0},
#   {'PlayerProfileId': 973, 'Points': 272.0},
#   {'PlayerProfileId': 976, 'Points': 81.0},
#   {'PlayerProfileId': 977, 'Points': 594.0},
#   {'PlayerProfileId': 978, 'Points': 189.0},
#   {'PlayerProfileId': 979, 'Points': 895.0},
#   {'PlayerProfileId': 980, 'Points': 315.0},
#   {'PlayerProfileId': 981, 'Points': 320.0},
#   {'PlayerProfileId': 983, 'Points': 90.0},
#   {'PlayerProfileId': 984, 'Points': 70.0},
#   {'PlayerProfileId': 985, 'Points': 2055.0},
#   {'PlayerProfileId': 986, 'Points': 366.0},
#   {'PlayerProfileId': 987, 'Points': 54.0},
#   {'PlayerProfileId': 988, 'Points': 54.0},
#   {'PlayerProfileId': 989, 'Points': 208.5},
#   {'PlayerProfileId': 990, 'Points': 54.0},
#   {'PlayerProfileId': 991, 'Points': 141.0},
#   {'PlayerProfileId': 992, 'Points': 54.0},
#   {'PlayerProfileId': 993, 'Points': 54.0},
#   {'PlayerProfileId': 994, 'Points': 54.0},
#   {'PlayerProfileId': 995, 'Points': 5.0},
#   {'PlayerProfileId': 996, 'Points': 5.0},
#   {'PlayerProfileId': 997, 'Points': 150.7},
#   {'PlayerProfileId': 998, 'Points': 5.0},
#   {'PlayerProfileId': 999, 'Points': 5.0},
#   {'PlayerProfileId': 1000, 'Points': 5.0},
#   {'PlayerProfileId': 1001, 'Points': 5.0},
#   {'PlayerProfileId': 1002, 'Points': 5.0},
#   {'PlayerProfileId': 1003, 'Points': 5.0},
#   {'PlayerProfileId': 1004, 'Points': 5.0},
#   {'PlayerProfileId': 1005, 'Points': 5.0},
#   {'PlayerProfileId': 1006, 'Points': 659.0},
#   {'PlayerProfileId': 1007, 'Points': 654.0},
#   {'PlayerProfileId': 1008, 'Points': 72.0},
#   {'PlayerProfileId': 1009, 'Points': 153.0},
#   {'PlayerProfileId': 1010, 'Points': 87.0},
#   {'PlayerProfileId': 1011, 'Points': 5.0},
#   {'PlayerProfileId': 1012, 'Points': 5.0},
#   {'PlayerProfileId': 1013, 'Points': 5.0},
#   {'PlayerProfileId': 1014, 'Points': 5.0},
#   {'PlayerProfileId': 1015, 'Points': 20.0},
#   {'PlayerProfileId': 1016, 'Points': 20.0},
#   {'PlayerProfileId': 1017, 'Points': 65.0},
#   {'PlayerProfileId': 1018, 'Points': 65.0},
#   {'PlayerProfileId': 1019, 'Points': 5.0},
#   {'PlayerProfileId': 1020, 'Points': 5.0},
#   {'PlayerProfileId': 1021, 'Points': 273.0},
#   {'PlayerProfileId': 1022, 'Points': 170.0},
#   {'PlayerProfileId': 1023, 'Points': 170.0},
#   {'PlayerProfileId': 1026, 'Points': 180.0},
#   {'PlayerProfileId': 1027, 'Points': 147.0},
#   {'PlayerProfileId': 1028, 'Points': 1890.0},
#   {'PlayerProfileId': 1029, 'Points': 76.0},
#   {'PlayerProfileId': 1030, 'Points': 198.0},
#   {'PlayerProfileId': 1031, 'Points': 286.0},
#   {'PlayerProfileId': 1032, 'Points': 286.0},
#   {'PlayerProfileId': 1033, 'Points': 198.0},
#   {'PlayerProfileId': 1034, 'Points': 66.0},
#   {'PlayerProfileId': 1035, 'Points': 15.0},
#   {'PlayerProfileId': 1036, 'Points': 525.0},
#   {'PlayerProfileId': 1037, 'Points': 360.0},
#   {'PlayerProfileId': 1038, 'Points': 5.0},
#   {'PlayerProfileId': 1039, 'Points': 5.0},
#   {'PlayerProfileId': 1040, 'Points': 5.0},
#   {'PlayerProfileId': 1044, 'Points': 20.0},
#   {'PlayerProfileId': 1045, 'Points': 5.0},
#   {'PlayerProfileId': 1046, 'Points': 1262.0},
#   {'PlayerProfileId': 1047, 'Points': 1600.0},
#   {'PlayerProfileId': 1048, 'Points': 4748.0},
#   {'PlayerProfileId': 1049, 'Points': 4594.0},
#   {'PlayerProfileId': 1051, 'Points': 600.0},
#   {'PlayerProfileId': 1052, 'Points': 1270.0},
#   {'PlayerProfileId': 1053, 'Points': 162.0},
#   {'PlayerProfileId': 1056, 'Points': 200.0},
#   {'PlayerProfileId': 1058, 'Points': 15.0},
#   {'PlayerProfileId': 1059, 'Points': 15.0},
#   {'PlayerProfileId': 1060, 'Points': 596.2},
#   {'PlayerProfileId': 1061, 'Points': 400.7},
#   {'PlayerProfileId': 1062, 'Points': 1326.0},
#   {'PlayerProfileId': 1063, 'Points': 220.0},
#   {'PlayerProfileId': 1068, 'Points': 1348.0},
#   {'PlayerProfileId': 1069, 'Points': 220.0},
#   {'PlayerProfileId': 1070, 'Points': 180.0},
#   {'PlayerProfileId': 1071, 'Points': 300.0},
#   {'PlayerProfileId': 1072, 'Points': 225.0},
#   {'PlayerProfileId': 1073, 'Points': 225.0},
#   {'PlayerProfileId': 1074, 'Points': 105.0},
#   {'PlayerProfileId': 1075, 'Points': 105.0},
#   {'PlayerProfileId': 1076, 'Points': 77.0},
#   {'PlayerProfileId': 1077, 'Points': 77.0},
#   {'PlayerProfileId': 1078, 'Points': 77.0},
#   {'PlayerProfileId': 1079, 'Points': 247.0},
#   {'PlayerProfileId': 1080, 'Points': 357.0},
#   {'PlayerProfileId': 1082, 'Points': 105.0},
#   {'PlayerProfileId': 1083, 'Points': 105.0},
#   {'PlayerProfileId': 1084, 'Points': 105.0},
#   {'PlayerProfileId': 1085, 'Points': 105.0},
#   {'PlayerProfileId': 1086, 'Points': 1851.0},
#   {'PlayerProfileId': 1087, 'Points': 154.0},
#   {'PlayerProfileId': 1088, 'Points': 154.0},
#   {'PlayerProfileId': 1089, 'Points': 154.0},
#   {'PlayerProfileId': 1090, 'Points': 154.0},
#   {'PlayerProfileId': 1091, 'Points': 154.0},
#   {'PlayerProfileId': 1092, 'Points': 484.0},
#   {'PlayerProfileId': 1093, 'Points': 154.0},
#   {'PlayerProfileId': 1095, 'Points': 184.0},
#   {'PlayerProfileId': 1096, 'Points': 638.0},
#   {'PlayerProfileId': 1097, 'Points': 334.0},
#   {'PlayerProfileId': 1098, 'Points': 184.0},
#   {'PlayerProfileId': 1099, 'Points': 308.0},
#   {'PlayerProfileId': 1100, 'Points': 154.0},
#   {'PlayerProfileId': 1101, 'Points': 169.0},
#   {'PlayerProfileId': 1102, 'Points': 340.5},
#   {'PlayerProfileId': 1103, 'Points': 471.5},
#   {'PlayerProfileId': 1104, 'Points': 192.0},
#   {'PlayerProfileId': 1105, 'Points': 231.0},
#   {'PlayerProfileId': 1106, 'Points': 58.0},
#   {'PlayerProfileId': 1107, 'Points': 5.0},
#   {'PlayerProfileId': 1108, 'Points': 5.0},
#   {'PlayerProfileId': 1109, 'Points': 5.0},
#   {'PlayerProfileId': 1110, 'Points': 38.0},
#   {'PlayerProfileId': 1111, 'Points': 1168.5},
#   {'PlayerProfileId': 1112, 'Points': 48.0},
#   {'PlayerProfileId': 1113, 'Points': 33.0},
#   {'PlayerProfileId': 1114, 'Points': 756.0},
#   {'PlayerProfileId': 1115, 'Points': 334.5},
#   {'PlayerProfileId': 1116, 'Points': 5.0},
#   {'PlayerProfileId': 1117, 'Points': 5.0},
#   {'PlayerProfileId': 1118, 'Points': 50.0},
#   {'PlayerProfileId': 1119, 'Points': 50.0},
#   {'PlayerProfileId': 1120, 'Points': 5.0},
#   {'PlayerProfileId': 1121, 'Points': 5.0},
#   {'PlayerProfileId': 1123, 'Points': 502.0},
#   {'PlayerProfileId': 1124, 'Points': 5.0},
#   {'PlayerProfileId': 1125, 'Points': 5.0},
#   {'PlayerProfileId': 1126, 'Points': 330.0},
#   {'PlayerProfileId': 1127, 'Points': 50.0},
#   {'PlayerProfileId': 1128, 'Points': 50.0},
#   {'PlayerProfileId': 1129, 'Points': 108.0},
#   {'PlayerProfileId': 1140, 'Points': 500.0},
#   {'PlayerProfileId': 1141, 'Points': 515.0},
#   {'PlayerProfileId': 1142, 'Points': 75.0},
#   {'PlayerProfileId': 1143, 'Points': 197.0},
#   {'PlayerProfileId': 1144, 'Points': 5.0},
#   {'PlayerProfileId': 1145, 'Points': 20.0},
#   {'PlayerProfileId': 1146, 'Points': 87.0},
#   {'PlayerProfileId': 1147, 'Points': 87.0},
#   {'PlayerProfileId': 1148, 'Points': 154.0},
#   {'PlayerProfileId': 1149, 'Points': 300.0},
#   {'PlayerProfileId': 1150, 'Points': 340.0},
#   {'PlayerProfileId': 1151, 'Points': 318.5},
#   {'PlayerProfileId': 1153, 'Points': 100.0},
#   {'PlayerProfileId': 1154, 'Points': 125.0},
#   {'PlayerProfileId': 1156, 'Points': 33.0},
#   {'PlayerProfileId': 1161, 'Points': 250.0},
#   {'PlayerProfileId': 1162, 'Points': 20.0},
#   {'PlayerProfileId': 1163, 'Points': 110.0},
#   {'PlayerProfileId': 1164, 'Points': 125.0},
#   {'PlayerProfileId': 1172, 'Points': 120.0},
#   {'PlayerProfileId': 1173, 'Points': 120.0},
#   {'PlayerProfileId': 1174, 'Points': 5.0},
#   {'PlayerProfileId': 1175, 'Points': 5.0},
#   {'PlayerProfileId': 1177, 'Points': 96.0},
#   {'PlayerProfileId': 1179, 'Points': 5.0},
#   {'PlayerProfileId': 1180, 'Points': 5.0},
#   {'PlayerProfileId': 1182, 'Points': 30.0},
#   {'PlayerProfileId': 1183, 'Points': 30.0},
#   {'PlayerProfileId': 1184, 'Points': 235.0},
#   {'PlayerProfileId': 1185, 'Points': 245.0},
#   {'PlayerProfileId': 1190, 'Points': 10.0},
#   {'PlayerProfileId': 1202, 'Points': 60.0},
#   {'PlayerProfileId': 1204, 'Points': 191.4},
#   {'PlayerProfileId': 1205, 'Points': 191.4},
#   {'PlayerProfileId': 1211, 'Points': 5.0},
#   {'PlayerProfileId': 1217, 'Points': 100.7},
#   {'PlayerProfileId': 1229, 'Points': 384.0},
#   {'PlayerProfileId': 1230, 'Points': 384.0},
#   {'PlayerProfileId': 1249, 'Points': 452.0},
#   {'PlayerProfileId': 1259, 'Points': 15.0},
#   {'PlayerProfileId': 1260, 'Points': 349.0},
#   {'PlayerProfileId': 1273, 'Points': 777.0},
#   {'PlayerProfileId': 1274, 'Points': 160.0},
#   {'PlayerProfileId': 1275, 'Points': 160.0},
#   {'PlayerProfileId': 1280, 'Points': 5.0},
#   {'PlayerProfileId': 1281, 'Points': 5.0},
#   {'PlayerProfileId': 1282, 'Points': 575.0},
#   {'PlayerProfileId': 1283, 'Points': 48.0},
#   {'PlayerProfileId': 1284, 'Points': 5.0},
#   {'PlayerProfileId': 1285, 'Points': 5.0},
#   {'PlayerProfileId': 1286, 'Points': 239.0},
#   {'PlayerProfileId': 1287, 'Points': 20.0},
#   {'PlayerProfileId': 1288, 'Points': 5.0},
#   {'PlayerProfileId': 1290, 'Points': 180.0},
#   {'PlayerProfileId': 1291, 'Points': 221.0},
#   {'PlayerProfileId': 1292, 'Points': 535.0},
#   {'PlayerProfileId': 1294, 'Points': 5.0},
#   {'PlayerProfileId': 1297, 'Points': 132.0},
#   {'PlayerProfileId': 1298, 'Points': 151.0},
#   {'PlayerProfileId': 1299, 'Points': 105.0},
#   {'PlayerProfileId': 1302, 'Points': 384.0},
#   {'PlayerProfileId': 1303, 'Points': 384.0},
#   {'PlayerProfileId': 1304, 'Points': 169.0},
#   {'PlayerProfileId': 1305, 'Points': 40.0},
#   {'PlayerProfileId': 1306, 'Points': 40.0},
#   {'PlayerProfileId': 1307, 'Points': 105.0},
#   {'PlayerProfileId': 1308, 'Points': 65.0},
#   {'PlayerProfileId': 1309, 'Points': 137.0},
#   {'PlayerProfileId': 1310, 'Points': 360.0},
#   {'PlayerProfileId': 1311, 'Points': 480.0},
#   {'PlayerProfileId': 1312, 'Points': 644.0},
#   {'PlayerProfileId': 1313, 'Points': 130.0},
#   {'PlayerProfileId': 1314, 'Points': 274.5},
#   {'PlayerProfileId': 1315, 'Points': 66.0},
#   {'PlayerProfileId': 1316, 'Points': 883.0},
#   {'PlayerProfileId': 1317, 'Points': 675.5},
#   {'PlayerProfileId': 1318, 'Points': 5.0},
#   {'PlayerProfileId': 1319, 'Points': 490.0},
#   {'PlayerProfileId': 1320, 'Points': 96.0},
#   {'PlayerProfileId': 1321, 'Points': 475.0},
#   {'PlayerProfileId': 1322, 'Points': 48.0},
#   {'PlayerProfileId': 1323, 'Points': 1584.0},
#   {'PlayerProfileId': 1324, 'Points': 574.0},
#   {'PlayerProfileId': 1325, 'Points': 33.0},
#   {'PlayerProfileId': 1327, 'Points': 70.0},
#   {'PlayerProfileId': 1328, 'Points': 200.0},
#   {'PlayerProfileId': 1329, 'Points': 740.0},
#   {'PlayerProfileId': 1330, 'Points': 5.0},
#   {'PlayerProfileId': 1331, 'Points': 5.0},
#   {'PlayerProfileId': 1332, 'Points': 120.0},
#   {'PlayerProfileId': 1333, 'Points': 75.0},
#   {'PlayerProfileId': 1334, 'Points': 70.0},
#   {'PlayerProfileId': 1335, 'Points': 70.0},
#   {'PlayerProfileId': 1337, 'Points': 35.0},
#   {'PlayerProfileId': 1339, 'Points': 60.0},
#   {'PlayerProfileId': 1340, 'Points': 817.0},
#   {'PlayerProfileId': 1341, 'Points': 105.0},
#   {'PlayerProfileId': 1342, 'Points': 105.0},
#   {'PlayerProfileId': 1344, 'Points': 180.0},
#   {'PlayerProfileId': 1345, 'Points': 780.0},
#   {'PlayerProfileId': 1346, 'Points': 100.0},
#   {'PlayerProfileId': 1348, 'Points': 660.0},
#   {'PlayerProfileId': 1349, 'Points': 33.0},
#   {'PlayerProfileId': 1350, 'Points': 33.0},
#   {'PlayerProfileId': 1351, 'Points': 5.0},
#   {'PlayerProfileId': 1352, 'Points': 5.0},
#   {'PlayerProfileId': 1353, 'Points': 33.0},
#   {'PlayerProfileId': 1354, 'Points': 33.0},
#   {'PlayerProfileId': 1355, 'Points': 5.0},
#   {'PlayerProfileId': 1356, 'Points': 5.0},
#   {'PlayerProfileId': 1357, 'Points': 963.0},
#   {'PlayerProfileId': 1358, 'Points': 495.0},
#   {'PlayerProfileId': 1359, 'Points': 60.0},
#   {'PlayerProfileId': 1360, 'Points': 620.0},
#   {'PlayerProfileId': 1361, 'Points': 48.0},
#   {'PlayerProfileId': 1362, 'Points': 200.0},
#   {'PlayerProfileId': 1363, 'Points': 185.0},
#   {'PlayerProfileId': 1364, 'Points': 355.0},
#   {'PlayerProfileId': 1365, 'Points': 648.0},
#   {'PlayerProfileId': 1367, 'Points': 99.5},
#   {'PlayerProfileId': 1368, 'Points': 20.0},
#   {'PlayerProfileId': 1369, 'Points': 100.7},
#   {'PlayerProfileId': 1370, 'Points': 5.0},
#   {'PlayerProfileId': 1373, 'Points': 5.0},
#   {'PlayerProfileId': 1374, 'Points': 5.0},
#   {'PlayerProfileId': 1375, 'Points': 242.0},
#   {'PlayerProfileId': 1376, 'Points': 1070.0},
#   {'PlayerProfileId': 1378, 'Points': 300.0},
#   {'PlayerProfileId': 1379, 'Points': 300.0},
#   {'PlayerProfileId': 1384, 'Points': 245.0},
#   {'PlayerProfileId': 1385, 'Points': 30.0},
#   {'PlayerProfileId': 1386, 'Points': 30.0},
#   {'PlayerProfileId': 1387, 'Points': 210.0},
#   {'PlayerProfileId': 1388, 'Points': 150.0},
#   {'PlayerProfileId': 1389, 'Points': 495.0},
#   {'PlayerProfileId': 1392, 'Points': 263.0},
#   {'PlayerProfileId': 1393, 'Points': 919.5},
#   {'PlayerProfileId': 1394, 'Points': 1376.0},
#   {'PlayerProfileId': 1395, 'Points': 180.0},
#   {'PlayerProfileId': 1396, 'Points': 420.0},
#   {'PlayerProfileId': 1397, 'Points': 247.50000000000003},
#   {'PlayerProfileId': 1401, 'Points': 166.0},
#   {'PlayerProfileId': 1403, 'Points': 317.0},
#   {'PlayerProfileId': 1421, 'Points': 240.0},
#   {'PlayerProfileId': 1422, 'Points': 240.0},
#   {'PlayerProfileId': 1423, 'Points': 154.0},
#   {'PlayerProfileId': 1425, 'Points': 492.0},
#   {'PlayerProfileId': 1426, 'Points': 612.0},
#   {'PlayerProfileId': 1433, 'Points': 227.0},
#   {'PlayerProfileId': 1434, 'Points': 77.0},
#   {'PlayerProfileId': 1435, 'Points': 144.0},
#   {'PlayerProfileId': 1441, 'Points': 77.0},
#   {'PlayerProfileId': 1442, 'Points': 92.0},
#   {'PlayerProfileId': 1444, 'Points': 5.0},
#   {'PlayerProfileId': 1445, 'Points': 5.0},
#   {'PlayerProfileId': 1465, 'Points': 15.0},
#   {'PlayerProfileId': 1473, 'Points': 169.0},
#   {'PlayerProfileId': 1476, 'Points': 279.0},
#   {'PlayerProfileId': 1478, 'Points': 211.0},
#   {'PlayerProfileId': 1480, 'Points': 486.0},
#   {'PlayerProfileId': 1481, 'Points': 30.0},
#   {'PlayerProfileId': 1482, 'Points': 30.0},
#   {'PlayerProfileId': 1483, 'Points': 62.0},
#   {'PlayerProfileId': 1484, 'Points': 62.0},
#   {'PlayerProfileId': 1485, 'Points': 67.0},
#   {'PlayerProfileId': 1486, 'Points': 40.7},
#   {'PlayerProfileId': 1487, 'Points': 34.0},
#   {'PlayerProfileId': 1488, 'Points': 34.0},
#   {'PlayerProfileId': 1489, 'Points': 34.0},
#   {'PlayerProfileId': 1490, 'Points': 34.0},
#   {'PlayerProfileId': 1491, 'Points': 240.0},
#   {'PlayerProfileId': 1492, 'Points': 81.0},
#   {'PlayerProfileId': 1493, 'Points': 858.0},
#   {'PlayerProfileId': 1494, 'Points': 575.0},
#   {'PlayerProfileId': 1499, 'Points': 967.0},
#   {'PlayerProfileId': 1501, 'Points': 180.0},
#   {'PlayerProfileId': 1502, 'Points': 180.0},
#   {'PlayerProfileId': 1509, 'Points': 49.50000000000001},
#   {'PlayerProfileId': 1510, 'Points': 49.50000000000001},
#   {'PlayerProfileId': 1511, 'Points': 40.0},
#   {'PlayerProfileId': 1522, 'Points': 240.0},
#   {'PlayerProfileId': 1524, 'Points': 35.0},
#   {'PlayerProfileId': 1525, 'Points': 35.0},
#   {'PlayerProfileId': 1526, 'Points': 15.0},
#   {'PlayerProfileId': 1527, 'Points': 15.0},
#   {'PlayerProfileId': 1528, 'Points': 1459.0},
#   {'PlayerProfileId': 1529, 'Points': 66.0},
#   {'PlayerProfileId': 1531, 'Points': 38.0},
#   {'PlayerProfileId': 1532, 'Points': 33.0},
#   {'PlayerProfileId': 1533, 'Points': 33.0},
#   {'PlayerProfileId': 1534, 'Points': 215.0},
#   {'PlayerProfileId': 1535, 'Points': 335.0},
#   {'PlayerProfileId': 1536, 'Points': 49.50000000000001},
#   {'PlayerProfileId': 1539, 'Points': 444.0},
#   {'PlayerProfileId': 1540, 'Points': 154.0},
#   {'PlayerProfileId': 1542, 'Points': 5.0},
#   {'PlayerProfileId': 1543, 'Points': 5.0},
#   {'PlayerProfileId': 1545, 'Points': 190.0},
#   {'PlayerProfileId': 1546, 'Points': 190.0},
#   {'PlayerProfileId': 1551, 'Points': 647.0},
#   {'PlayerProfileId': 1552, 'Points': 15.0},
#   {'PlayerProfileId': 1553, 'Points': 15.0},
#   {'PlayerProfileId': 1554, 'Points': 300.0},
#   {'PlayerProfileId': 1556, 'Points': 615.0},
#   {'PlayerProfileId': 1559, 'Points': 70.0},
#   {'PlayerProfileId': 1560, 'Points': 169.0},
#   {'PlayerProfileId': 1561, 'Points': 180.0},
#   {'PlayerProfileId': 1562, 'Points': 15.0},
#   {'PlayerProfileId': 1563, 'Points': 15.0},
#   {'PlayerProfileId': 1564, 'Points': 77.0},
#   {'PlayerProfileId': 1565, 'Points': 77.0},
#   {'PlayerProfileId': 1566, 'Points': 70.0},
#   {'PlayerProfileId': 1567, 'Points': 140.0},
#   {'PlayerProfileId': 1568, 'Points': 70.0},
#   {'PlayerProfileId': 1569, 'Points': 70.0},
#   {'PlayerProfileId': 1570, 'Points': 300.0},
#   {'PlayerProfileId': 1571, 'Points': 140.0},
#   {'PlayerProfileId': 1572, 'Points': 115.0},
#   {'PlayerProfileId': 1573, 'Points': 33.0},
#   {'PlayerProfileId': 1574, 'Points': 66.0},
#   {'PlayerProfileId': 1575, 'Points': 66.0},
#   {'PlayerProfileId': 1576, 'Points': 10.0},
#   {'PlayerProfileId': 1577, 'Points': 10.0},
#   {'PlayerProfileId': 1578, 'Points': 184.0},
#   {'PlayerProfileId': 1579, 'Points': 64.5},
#   {'PlayerProfileId': 1580, 'Points': 229.5},
#   {'PlayerProfileId': 1582, 'Points': 195.0},
#   {'PlayerProfileId': 1583, 'Points': 300.0},
#   {'PlayerProfileId': 1584, 'Points': 154.0},
#   {'PlayerProfileId': 1585, 'Points': 154.0},
#   {'PlayerProfileId': 1586, 'Points': 92.0},
#   {'PlayerProfileId': 1587, 'Points': 15.0},
#   {'PlayerProfileId': 1589, 'Points': 45.0},
#   {'PlayerProfileId': 1590, 'Points': 45.0},
#   {'PlayerProfileId': 1593, 'Points': 15.0},
#   {'PlayerProfileId': 1594, 'Points': 15.0},
#   {'PlayerProfileId': 1596, 'Points': 180.0},
#   {'PlayerProfileId': 1598, 'Points': 152.5},
#   {'PlayerProfileId': 1604, 'Points': 140.0},
#   {'PlayerProfileId': 1605, 'Points': 140.0},
#   {'PlayerProfileId': 1606, 'Points': 120.0},
#   {'PlayerProfileId': 1612, 'Points': 200.0},
#   {'PlayerProfileId': 1613, 'Points': 222.0},
#   {'PlayerProfileId': 1614, 'Points': 49.50000000000001},
#   {'PlayerProfileId': 1615, 'Points': 15.0},
#   {'PlayerProfileId': 1616, 'Points': 153.0},
#   {'PlayerProfileId': 1619, 'Points': 96.0},
#   {'PlayerProfileId': 1620, 'Points': 160.0},
#   {'PlayerProfileId': 1621, 'Points': 162.0},
#   {'PlayerProfileId': 1622, 'Points': 162.0},
#   {'PlayerProfileId': 1623, 'Points': 92.0},
#   {'PlayerProfileId': 1624, 'Points': 92.0},
#   {'PlayerProfileId': 1627, 'Points': 180.0},
#   {'PlayerProfileId': 1628, 'Points': 180.0},
#   {'PlayerProfileId': 1631, 'Points': 82.0},
#   {'PlayerProfileId': 1637, 'Points': 77.0},
#   {'PlayerProfileId': 1638, 'Points': 322.0},
#   {'PlayerProfileId': 1639, 'Points': 427.0},
#   {'PlayerProfileId': 1640, 'Points': 5.0},
#   {'PlayerProfileId': 1641, 'Points': 5.0},
#   {'PlayerProfileId': 1643, 'Points': 5.0},
#   {'PlayerProfileId': 1650, 'Points': 115.50000000000001},
#   {'PlayerProfileId': 1651, 'Points': 365.0},
#   {'PlayerProfileId': 1652, 'Points': 260.0},
#   {'PlayerProfileId': 1653, 'Points': 303.0},
#   {'PlayerProfileId': 1654, 'Points': 38.0},
#   {'PlayerProfileId': 1660, 'Points': 15.0},
#   {'PlayerProfileId': 1661, 'Points': 15.0},
#   {'PlayerProfileId': 1663, 'Points': 120.0},
#   {'PlayerProfileId': 1667, 'Points': 15.0},
#   {'PlayerProfileId': 1668, 'Points': 15.0},
#   {'PlayerProfileId': 1669, 'Points': 90.0},
#   {'PlayerProfileId': 1670, 'Points': 85.0},
#   {'PlayerProfileId': 1671, 'Points': 15.0},
#   {'PlayerProfileId': 1675, 'Points': 48.0},
#   {'PlayerProfileId': 1676, 'Points': 48.0},
#   {'PlayerProfileId': 1679, 'Points': 68.5},
#   {'PlayerProfileId': 1680, 'Points': 222.0},
#   {'PlayerProfileId': 1681, 'Points': 222.0},
#   {'PlayerProfileId': 1687, 'Points': 81.0},
#   {'PlayerProfileId': 1690, 'Points': 150.0},
#   {'PlayerProfileId': 1691, 'Points': 150.0},
#   {'PlayerProfileId': 1692, 'Points': 48.0},
#   {'PlayerProfileId': 1693, 'Points': 33.0},
#   {'PlayerProfileId': 1694, 'Points': 105.0},
#   {'PlayerProfileId': 1695, 'Points': 105.0},
#   {'PlayerProfileId': 1696, 'Points': 66.0},
#   {'PlayerProfileId': 1697, 'Points': 66.0},
#   {'PlayerProfileId': 1698, 'Points': 120.0},
#   {'PlayerProfileId': 1699, 'Points': 120.0},
#   {'PlayerProfileId': 1700, 'Points': 87.0},
#   {'PlayerProfileId': 1701, 'Points': 87.0},
#   {'PlayerProfileId': 1702, 'Points': 96.0},
#   {'PlayerProfileId': 1703, 'Points': 96.0},
#   {'PlayerProfileId': 1704, 'Points': 37.0},
#   {'PlayerProfileId': 1707, 'Points': 35.0},
#   {'PlayerProfileId': 1708, 'Points': 35.0},
#   {'PlayerProfileId': 1709, 'Points': 169.0},
#   {'PlayerProfileId': 1710, 'Points': 235.0},
#   {'PlayerProfileId': 1711, 'Points': 220.0},
#   {'PlayerProfileId': 1714, 'Points': 150.0},
#   {'PlayerProfileId': 1716, 'Points': 240.0},
#   {'PlayerProfileId': 1718, 'Points': 30.0},
#   {'PlayerProfileId': 1719, 'Points': 30.0},
#   {'PlayerProfileId': 1720, 'Points': 15.0},
#   {'PlayerProfileId': 1721, 'Points': 30.0},
#   {'PlayerProfileId': 1723, 'Points': 455.00000000000006},
#   {'PlayerProfileId': 1724, 'Points': 277.0},
#   {'PlayerProfileId': 1725, 'Points': 77.0},
#   {'PlayerProfileId': 1727, 'Points': 30.0},
#   {'PlayerProfileId': 1728, 'Points': 30.0},
#   {'PlayerProfileId': 1730, 'Points': 80.0},
#   {'PlayerProfileId': 1732, 'Points': 96.0},
#   {'PlayerProfileId': 1733, 'Points': 96.0},
#   {'PlayerProfileId': 1734, 'Points': 30.0},
#   {'PlayerProfileId': 1735, 'Points': 30.0},
#   {'PlayerProfileId': 1736, 'Points': 17.0},
#   {'PlayerProfileId': 1737, 'Points': 17.0},
#   {'PlayerProfileId': 1739, 'Points': 5.0},
#   {'PlayerProfileId': 1740, 'Points': 5.0},
#   {'PlayerProfileId': 1741, 'Points': 5.0},
#   {'PlayerProfileId': 1742, 'Points': 5.0},
#   {'PlayerProfileId': 1743, 'Points': 16.5},
#   {'PlayerProfileId': 1744, 'Points': 31.5},
#   {'PlayerProfileId': 1745, 'Points': 5.0},
#   {'PlayerProfileId': 1746, 'Points': 5.0},
#   {'PlayerProfileId': 1747, 'Points': 16.5},
#   {'PlayerProfileId': 1748, 'Points': 16.5},
#   {'PlayerProfileId': 1749, 'Points': 323.5},
#   {'PlayerProfileId': 1751, 'Points': 16.5},
#   {'PlayerProfileId': 1752, 'Points': 16.5},
#   {'PlayerProfileId': 1753, 'Points': 77.0},
#   {'PlayerProfileId': 1754, 'Points': 5.0},
#   {'PlayerProfileId': 1755, 'Points': 5.0},
#   {'PlayerProfileId': 1756, 'Points': 5.0},
#   {'PlayerProfileId': 1758, 'Points': 5.0},
#   {'PlayerProfileId': 1759, 'Points': 5.0},
#   {'PlayerProfileId': 1760, 'Points': 92.0},
#   {'PlayerProfileId': 1761, 'Points': 1200.0},
#   {'PlayerProfileId': 1763, 'Points': 300.0},
#   {'PlayerProfileId': 1764, 'Points': 80.0},
#   {'PlayerProfileId': 1765, 'Points': 68.0},
#   {'PlayerProfileId': 1766, 'Points': 33.0},
#   {'PlayerProfileId': 1767, 'Points': 225.0},
#   {'PlayerProfileId': 1768, 'Points': 264.0},
#   {'PlayerProfileId': 1771, 'Points': 105.0},
#   {'PlayerProfileId': 1772, 'Points': 105.0},
#   {'PlayerProfileId': 1779, 'Points': 670.0},
#   {'PlayerProfileId': 1782, 'Points': 33.0},
#   {'PlayerProfileId': 1783, 'Points': 33.0},
#   {'PlayerProfileId': 1785, 'Points': 154.0},
#   {'PlayerProfileId': 1794, 'Points': 77.0},
#   {'PlayerProfileId': 1802, 'Points': 190.0},
#   {'PlayerProfileId': 1803, 'Points': 190.0},
#   {'PlayerProfileId': 1804, 'Points': 288.0},
#   {'PlayerProfileId': 1805, 'Points': 60.0},
#   {'PlayerProfileId': 1812, 'Points': 66.0},
#   {'PlayerProfileId': 1813, 'Points': 66.0},
#   {'PlayerProfileId': 1815, 'Points': 15.0},
#   {'PlayerProfileId': 1816, 'Points': 30.0},
#   {'PlayerProfileId': 1823, 'Points': 15.0},
#   {'PlayerProfileId': 1824, 'Points': 15.0},
#   {'PlayerProfileId': 1837, 'Points': 120.0},
#   {'PlayerProfileId': 1838, 'Points': 120.0},
#   {'PlayerProfileId': 1839, 'Points': 465.0},
#   {'PlayerProfileId': 1840, 'Points': 30.0},
#   {'PlayerProfileId': 1842, 'Points': 555.0},
#   {'PlayerProfileId': 1843, 'Points': 675.0},
#   {'PlayerProfileId': 1844, 'Points': 180.0},
#   {'PlayerProfileId': 1845, 'Points': 180.0},
#   {'PlayerProfileId': 1846, 'Points': 1095.0},
#   {'PlayerProfileId': 1847, 'Points': 15.0},
#   {'PlayerProfileId': 1848, 'Points': 33.0},
#   {'PlayerProfileId': 1851, 'Points': 1507.0},
#   {'PlayerProfileId': 1852, 'Points': 834.5},
#   {'PlayerProfileId': 1853, 'Points': 147.0},
#   {'PlayerProfileId': 1854, 'Points': 77.0},
#   {'PlayerProfileId': 1855, 'Points': 105.0},
#   {'PlayerProfileId': 1856, 'Points': 105.0},
#   {'PlayerProfileId': 1857, 'Points': 1246.0},
#   {'PlayerProfileId': 1859, 'Points': 225.0},
#   {'PlayerProfileId': 1860, 'Points': 225.0},
#   {'PlayerProfileId': 1861, 'Points': 571.5},
#   {'PlayerProfileId': 1862, 'Points': 438.0},
#   {'PlayerProfileId': 1863, 'Points': 111.0},
#   {'PlayerProfileId': 1864, 'Points': 264.0},
#   {'PlayerProfileId': 1866, 'Points': 120.0},
#   {'PlayerProfileId': 1867, 'Points': 120.0},
#   {'PlayerProfileId': 1868, 'Points': 33.0},
#   {'PlayerProfileId': 1869, 'Points': 15.0},
#   {'PlayerProfileId': 1870, 'Points': 15.0},
#   {'PlayerProfileId': 1871, 'Points': 5.0},
#   {'PlayerProfileId': 1872, 'Points': 5.0},
#   {'PlayerProfileId': 1873, 'Points': 33.0},
#   {'PlayerProfileId': 1874, 'Points': 33.0},
#   {'PlayerProfileId': 1875, 'Points': 35.0},
#   {'PlayerProfileId': 1876, 'Points': 215.0},
#   {'PlayerProfileId': 1878, 'Points': 380.0},
#   {'PlayerProfileId': 1879, 'Points': 380.0},
#   {'PlayerProfileId': 1880, 'Points': 33.0},
#   {'PlayerProfileId': 1881, 'Points': 33.0},
#   {'PlayerProfileId': 1882, 'Points': 70.0},
#   {'PlayerProfileId': 1883, 'Points': 70.0},
#   {'PlayerProfileId': 1884, 'Points': 60.0},
#   {'PlayerProfileId': 1885, 'Points': 60.0},
#   {'PlayerProfileId': 1886, 'Points': 5.0},
#   {'PlayerProfileId': 1887, 'Points': 330.0},
#   {'PlayerProfileId': 1888, 'Points': 330.0},
#   {'PlayerProfileId': 1890, 'Points': 15.0},
#   {'PlayerProfileId': 1891, 'Points': 15.0},
#   {'PlayerProfileId': 1892, 'Points': 252.0},
#   {'PlayerProfileId': 1893, 'Points': 140.0},
#   {'PlayerProfileId': 1894, 'Points': 250.00000000000003},
#   {'PlayerProfileId': 1896, 'Points': 80.0},
#   {'PlayerProfileId': 1899, 'Points': 450.0},
#   {'PlayerProfileId': 1900, 'Points': 450.0},
#   {'PlayerProfileId': 1901, 'Points': 60.0},
#   {'PlayerProfileId': 1902, 'Points': 60.0},
#   {'PlayerProfileId': 1904, 'Points': 70.0},
#   {'PlayerProfileId': 1905, 'Points': 70.0},
#   {'PlayerProfileId': 1907, 'Points': 105.0},
#   {'PlayerProfileId': 1908, 'Points': 105.0},
#   {'PlayerProfileId': 1909, 'Points': 825.0},
#   {'PlayerProfileId': 1911, 'Points': 255.0},
#   {'PlayerProfileId': 1912, 'Points': 155.0},
#   {'PlayerProfileId': 1913, 'Points': 155.0},
#   ...]}

# %%
#Verify dates are the same for all rankings,check the amount of rankings available, and the min/max dates in rankings
print(
    [x['AsOf'] for x in  aau_raw_rankings]==[x['AsOf'] for x in  bvne_raw_rankings], #aau vs bvne date list comparison
    [x['AsOf'] for x in  aau_raw_rankings]==[x['AsOf'] for x in  p1440_raw_rankings], #aau vs p1440 date list comparison
    len(aau_raw_rankings),
    aau_raw_rankings[0]['AsOf'],
    aau_raw_rankings[-1]['AsOf'],sep='\n'
)
# Out:
# True
# True
# 182
# 2019-01-07T00:00:00
# 2022-06-27T00:00:00

# %%
#Convert date strings to datetime format and store in date list
aau_dt_holder=sorted([dt.strptime(x.get('AsOf'),'%Y-%m-%dT%H:%M:%S') for x in aau_raw_rankings])
bvne_dt_holder=sorted([dt.strptime(x.get('AsOf'),'%Y-%m-%dT%H:%M:%S') for x in bvne_raw_rankings])
p1440_dt_holder=sorted([dt.strptime(x.get('AsOf'),'%Y-%m-%dT%H:%M:%S') for x in p1440_raw_rankings])

aau_dt_holder[0:5]
# Out:
# [datetime.datetime(2019, 1, 7, 0, 0),
#  datetime.datetime(2019, 1, 14, 0, 0),
#  datetime.datetime(2019, 1, 21, 0, 0),
#  datetime.datetime(2019, 1, 28, 0, 0),
#  datetime.datetime(2019, 2, 4, 0, 0)]

# %%
#Create new ranking dictionaries based on points earned and another by position relative to competitors
#Only creating Keys based on dates provided, values will be added below
#IMPORTANT: Higher points is better while lower position is better
aau_point_rankings={k:[] for k in aau_dt_holder}
bvne_point_rankings={k:[] for k in bvne_dt_holder}
p1440_point_rankings={k:[] for k in p1440_dt_holder}

aau_positional_rankings={k:[] for k in aau_dt_holder}
bvne_positional_rankings={k:[] for k in bvne_dt_holder}
p1440_positional_rankings={k:[] for k in p1440_dt_holder}

# %%
#Function to fill values in dictionary for point based dictionary
#Values are a dictionary of every player:point total
#Function will update the third parameter (new_dict) in place and requires no return
#This format is used over original format from JSON file that had similar information for optimized look up speed
def fill_point_rankings(dt_holder,raw_rankings,new_dict):
    for i in dt_holder:
        dict_holder={}
        for j in raw_rankings:
            if i==dt.strptime(j.get('AsOf'),'%Y-%m-%dT%H:%M:%S'):
                for k in j.get('Players'):
                    dict_holder[k.get('PlayerProfileId')]=k.get('Points')
                new_dict[i]=dict_holder
                
#Update point rankings
fill_point_rankings(aau_dt_holder,aau_raw_rankings,aau_point_rankings)
fill_point_rankings(bvne_dt_holder,bvne_raw_rankings,bvne_point_rankings)
fill_point_rankings(p1440_dt_holder,p1440_raw_rankings,p1440_point_rankings)

# %%
#Function to fill values in dictionary for positional based dictionary
#Values are a dictionary of every player:relative position (lower is better)
#Function will update the third parameter (new_dict) in place and requires no return
#This format is used over original format from JSON file that had similar information for optimized look up speed
def fill_positional_rankings(dt_holder,raw_rankings,new_dict):
    for i in dt_holder:
        dict_holder={}
        for j in raw_rankings:
            if i==dt.strptime(j.get('AsOf'),'%Y-%m-%dT%H:%M:%S'):
                for k in j.get('Players'):
                    dict_holder[k.get('PlayerProfileId')]=k.get('Points')
                ratings={key: val for key, val in sorted(dict_holder.items(), key=lambda item: item[1],reverse=True)}
                positional_dict_holder=dict(zip(ratings.keys(), rankdata([-i for i in ratings.values()], method='average')))
                new_dict[i]=positional_dict_holder
                
#Update positional rankings       
fill_positional_rankings(aau_dt_holder,aau_raw_rankings,aau_positional_rankings)
fill_positional_rankings(bvne_dt_holder,bvne_raw_rankings,bvne_positional_rankings)
fill_positional_rankings(p1440_dt_holder,p1440_raw_rankings,p1440_positional_rankings)

# %%
#Bring in all match data provided
with open('/Users/cameron/Documents/SMU_DS/Capstone/SMU_Capstone_Project/Pickle_Files/vball_game_data.pbz2', 'rb') as file:
    uncompressed = bz2.BZ2File(file)
    vball = pickle.load(uncompressed)

with open('/Users/cameron/Documents/SMU_DS/Capstone/SMU_Capstone_Project/Pickle_Files/new_vball_game_data_alt.pbz2', 'rb') as file:
    uncompressed = bz2.BZ2File(file)
    vball_new = pickle.load(uncompressed)
    
vball_new_clean=vball_new[(vball_new['datetime'] >= max(vball['datetime']))]
vball_all=np.concatenate((vball, vball_new_clean))

# %%
#Column names reminder
vball_all.dtype
# Out:
# dtype([('tournamentId', '<i4'), ('tournament_name', '<U200'), ('type', '<U200'), ('division', '<U200'), ('divisionId', '<U200'), ('gender', '<U200'), ('age_type', '<U200'), ('match_id', '<i4'), ('roundNumber', '<i4'), ('matchNumber', '<i4'), ('matchWinner', '<U200'), ('series_number', '<i4'), ('match_type', '<U200'), ('isMatch', '?'), ('player_id', '<i4'), ('teammate_id', '<i4'), ('team_id', '<U200'), ('opponent1_id', '<i4'), ('opponent2_id', '<i4'), ('opponent_team_id', '<U200'), ('win', '?'), ('ignored_score', '?'), ('team_score', '<i4'), ('opponent_score', '<i4'), ('incomplete_score', '?'), ('required_score', '<i4'), ('score_differential', '<i4'), ('pct_points_won', '<f4'), ('winning_score', '<i4'), ('latitude', '<f4'), ('longitude', '<f4'), ('time_zone', '<U200'), ('datetime', '<M8[us]')])

# %%
#Function to predict games for every available match based on ranking system inputted
#Function returns dictionary of outcomes
#Match will refer to latest rankings provided relative to match date
#Imputation process is to use partner's ranking if available (will not evaluate if full team missing)
#If imputation is false, all players must be present to evaluate
#max_is_higher used to adjust if lower or higher is better in ranking
#better_player_weight allows you to tune the weight of the blended ranking of the players
#start_date allows you to specify a manual start date

def predict_games(df,new_dict,dt_holder,max_is_higher=True,impute=True,better_player_weight=.5,start_date=None):
    
    #If match before the first rankings or before inputted start date, match will not be evaluated
    #If match after 7 days of last ranking, match will not be evaluated
    if start_date==None or start_date<=min(list(new_dict.keys())):
        adj_df=df[df['datetime']>=min(list(new_dict.keys()))]
        adj_df=adj_df[adj_df['datetime']<(max(list(new_dict.keys()))+ timedelta(days=7))]
    else:
        new_start_date=max([x for x in dt_holder if x<=start_date])
        adj_df=df[df['datetime']>=new_start_date]
        adj_df=adj_df[adj_df['datetime']<(max(list(new_dict.keys()))+ timedelta(days=7))]
        
    #Iterate through every match and store results by appending one at a time    
    result_holder=[]
    for i in adj_df[::4]:
        
        #Find date of last ranking provided
        date_check_holder=max([x for x in dt_holder if x<i['datetime']])
        rankings=new_dict.get(date_check_holder)
        
        #Update teams and match result
        team_ids=[i['player_id'],i['teammate_id']]
        opponent_ids=[i['opponent1_id'],i['opponent2_id']]
        match_result=i['win']
        
        #Check if there is sufficient data for match evaluation depending on if imputation is allowed (available_data_check)
        #Example in cell below how any and all work with dictionaries
        if impute==True:
            available_data_check=(any(x in rankings for x in team_ids) and any(x in rankings for x in opponent_ids))
        else:
            available_data_check=(all(x in rankings for x in team_ids) and all(x in rankings for x in opponent_ids))

        #Only evaluate if data is available, else mark as skipped
        if available_data_check==True: 
            
            #Sort team ratings so that you can control weight of better player
            #Sort order changes based on whether ranking is ascending or descending
            if max_is_higher==True:
                team_ranking_holder=sorted([rankings.get(team_ids[0],rankings.get(team_ids[1])),rankings.get(team_ids[1],rankings.get(team_ids[0]))])
                opponent_ranking_holder=sorted([rankings.get(opponent_ids[0],rankings.get(opponent_ids[1])),rankings.get(opponent_ids[1],rankings.get(opponent_ids[0]))])
            else:
                team_ranking_holder=sorted([rankings.get(team_ids[0],rankings.get(team_ids[1])),rankings.get(team_ids[1],rankings.get(team_ids[0]))],reverse=True)
                opponent_ranking_holder=sorted([rankings.get(opponent_ids[0],rankings.get(opponent_ids[1])),rankings.get(opponent_ids[1],rankings.get(opponent_ids[0]))],reverse=True)
                                
            team_ranking=team_ranking_holder[0]*(1-better_player_weight)+team_ranking_holder[1]*better_player_weight
            opponent_ranking=opponent_ranking_holder[0]*(1-better_player_weight)+opponent_ranking_holder[1]*better_player_weight
            
            #Update result based on blended ranking of teams
            if team_ranking==opponent_ranking:
                result_holder.append('tie') #predicted tie
            elif max(team_ranking,opponent_ranking)==team_ranking and match_result==True and max_is_higher==True: #Adjust min/max depending on points vs positional ranking
                result_holder.append('correct') #correct prediction
            elif min(team_ranking,opponent_ranking)==team_ranking and match_result==True and max_is_higher==False: #Adjust min/max depending on points vs positional ranking
                result_holder.append('correct') #correct prediction
            else:
                result_holder.append('incorrect') #incorrect prediction
        
        else:
            result_holder.append('skipped-unranked team')
        
        # print(date_check_holder,team_ranking,opponent_ranking,match_result)

    results=Counter(result_holder)
    return results

# %%
#Example of how any and all work with dictionaries
#Searches for keys
#'Any' means at least 1 while 'all' means every element must match
test={0:'hi',1:'low',2:'yo'}
case1=[0,1]
case2=[0,3]
case3=[3,4]
print(
    any(x in test for x in case1),
    any(x in test for x in case2),
    any(x in test for x in case3),
    all(x in test for x in case1),
    all(x in test for x in case2),
    all(x in test for x in case3),sep='\n'
)
# Out:
# True
# True
# False
# True
# False
# False

# %% [markdown]
# ### Points Ranking Evaluation With Imputation (50/50 weight balance)

# %%
#AAU points rankings with imputation
results=predict_games(vball_all,aau_point_rankings,aau_dt_holder,max_is_higher=True,impute=True,better_player_weight=.5,start_date=None)
print(results)
print('accuracy:',results['correct']/(results['correct']+results['incorrect']))
# Out:
# Counter({'skipped-unranked team': 26882, 'incorrect': 17746, 'correct': 15314, 'tie': 224})
# accuracy: 0.4632183908045977

# %%
#BVNE points rankings with imputation
results=predict_games(vball_all,bvne_point_rankings,bvne_dt_holder,max_is_higher=True,impute=True,better_player_weight=.5,start_date=None)
print(results)
print('accuracy:',results['correct']/(results['correct']+results['incorrect']))
# Out:
# Counter({'skipped-unranked team': 40200, 'incorrect': 11215, 'correct': 8576, 'tie': 175})
# accuracy: 0.43332828053155475

# %%
#p1440 points rankings with imputation
results=predict_games(vball_all,p1440_point_rankings,p1440_dt_holder,max_is_higher=True,impute=True,better_player_weight=.5,start_date=None)
print(results)
print('accuracy:',results['correct']/(results['correct']+results['incorrect']))
# Out:
# Counter({'skipped-unranked team': 43118, 'incorrect': 9956, 'correct': 6838, 'tie': 254})
# accuracy: 0.40716922710491843

# %% [markdown]
# ### Positional Ranking Evaluation With Imputation (50/50 weight balance)

# %%
#AAU positional rankings with imputation
results=predict_games(vball_all,aau_positional_rankings,aau_dt_holder,max_is_higher=False,impute=True,better_player_weight=.5,start_date=None)
print(results)
print('accuracy:',results['correct']/(results['correct']+results['incorrect']))

# Previous points with imputation
# Counter({'skipped-unranked team': 26882, 'incorrect': 17746, 'correct': 15314, 'tie': 224})
# accuracy: 0.4632183908045977
# Out:
# Counter({'skipped-unranked team': 26882, 'incorrect': 18128, 'correct': 14933, 'tie': 223})
# accuracy: 0.4516802274583346

# %%
#BVNE positional rankings with imputation
results=predict_games(vball_all,bvne_positional_rankings,bvne_dt_holder,max_is_higher=False,impute=True,better_player_weight=.5,start_date=None)
print(results)
print('accuracy:',results['correct']/(results['correct']+results['incorrect']))

# Previous points with imputation
# Counter({'skipped-unranked team': 40200, 'incorrect': 11215, 'correct': 8576, 'tie': 175})
# accuracy: 0.43332828053155475
# Out:
# Counter({'skipped-unranked team': 40200, 'incorrect': 11379, 'correct': 8425, 'tie': 162})
# accuracy: 0.4254191072510604

# %%
#p1440 positional rankings with imputation
results=predict_games(vball_all,p1440_positional_rankings,p1440_dt_holder,max_is_higher=False,impute=True,better_player_weight=.5,start_date=None)
print(results)
print('accuracy:',results['correct']/(results['correct']+results['incorrect']))

# Previous points with imputation
# Counter({'skipped-unranked team': 43118, 'incorrect': 9956, 'correct': 6838, 'tie': 254})
# accuracy: 0.40716922710491843
# Out:
# Counter({'skipped-unranked team': 43118, 'incorrect': 10026, 'correct': 6763, 'tie': 259})
# accuracy: 0.40282327714575017

# %% [markdown]
# ### Points Ranking Evaluation Without Imputation (50/50 weight balance)
# Because points rankings were higher

# %%
#AAU points rankings without imputation
results=predict_games(vball_all,aau_point_rankings,aau_dt_holder,max_is_higher=True,impute=False,better_player_weight=.5,start_date=None)
print(results)
print('accuracy:',results['correct']/(results['correct']+results['incorrect']))

# Previous points with imputation
# Counter({'skipped-unranked team': 26882, 'incorrect': 17746, 'correct': 15314, 'tie': 224})
# accuracy: 0.4632183908045977
# Out:
# Counter({'skipped-unranked team': 40739, 'incorrect': 10367, 'correct': 9027, 'tie': 33})
# accuracy: 0.465453232958647

# %%
#BVNE points rankings without imputation
results=predict_games(vball_all,bvne_point_rankings,bvne_dt_holder,max_is_higher=True,impute=False,better_player_weight=.5,start_date=None)
print(results)
print('accuracy:',results['correct']/(results['correct']+results['incorrect']))

# Previous points with imputation
# Counter({'skipped-unranked team': 40200, 'incorrect': 11215, 'correct': 8576, 'tie': 175})
# accuracy: 0.43332828053155475
# Out:
# Counter({'skipped-unranked team': 51529, 'incorrect': 4816, 'correct': 3804, 'tie': 17})
# accuracy: 0.44129930394431555

# %%
#p1440 points rankings without imputation
results=predict_games(vball_all,p1440_point_rankings,p1440_dt_holder,max_is_higher=True,impute=False,better_player_weight=.5,start_date=None)
print(results)
print('accuracy:',results['correct']/(results['correct']+results['incorrect']))

# Previous points with imputation
# Counter({'skipped-unranked team': 43118, 'incorrect': 9956, 'correct': 6838, 'tie': 254})
# accuracy: 0.40716922710491843
# Out:
# Counter({'skipped-unranked team': 52573, 'incorrect': 4570, 'correct': 2989, 'tie': 34})
# accuracy: 0.3954226749570049

# %% [markdown]
# ### Points Ranking Evaluation With Imputation (Adjusting the weight balance in favor of better player)
# Because points rankings were higher and imputation had a minor drop off with significantly more predicitons

# %%
#AAU points rankings with imputation adjusting weight balance
aau_acc=[]
for i in [1-x/10 for x in range(5)]:
    results=predict_games(vball_all,aau_point_rankings,aau_dt_holder,max_is_higher=True,impute=True,better_player_weight=i,start_date=None)
    print('Better player weight:',i)
    print(results)
    print('accuracy:',results['correct']/(results['correct']+results['incorrect']))
    print('')
    aau_acc.append(results['correct']/(results['correct']+results['incorrect']))

# Previous points with imputation
# Counter({'skipped-unranked team': 26882, 'incorrect': 17746, 'correct': 15314, 'tie': 224})
# accuracy: 0.4632183908045977
# Out:
# Better player weight: 1.0
# Counter({'skipped-unranked team': 26882, 'incorrect': 17637, 'correct': 15360, 'tie': 287})
# accuracy: 0.46549686335121376
#
#
# Better player weight: 0.9
# Counter({'skipped-unranked team': 26882, 'incorrect': 17674, 'correct': 15387, 'tie': 223})
# accuracy: 0.46541241946704576
#
#
# Better player weight: 0.8
# Counter({'skipped-unranked team': 26882, 'incorrect': 17678, 'correct': 15382, 'tie': 224})
# accuracy: 0.465275257108288
#
#
# Better player weight: 0.7
# Counter({'skipped-unranked team': 26882, 'incorrect': 17685, 'correct': 15379, 'tie': 220})
# accuracy: 0.46512823614807647
#
#
# Better player weight: 0.6
# Counter({'skipped-unranked team': 26882, 'incorrect': 17708, 'correct': 15350, 'tie': 226})
# accuracy: 0.4643354104906528

# %%
#BVNE points rankings with imputation adjusting weight balance
bvne_acc=[]
for i in [1-x/10 for x in range(5)]:
    results=predict_games(vball_all,bvne_point_rankings,bvne_dt_holder,max_is_higher=True,impute=True,better_player_weight=i,start_date=None)
    print('Better player weight:',i)
    print(results)
    print('accuracy:',results['correct']/(results['correct']+results['incorrect']))
    print('')
    bvne_acc.append(results['correct']/(results['correct']+results['incorrect']))

# Previous points with imputation
# Counter({'skipped-unranked team': 40200, 'incorrect': 11215, 'correct': 8576, 'tie': 175})
# accuracy: 0.43332828053155475
# Out:
# Better player weight: 1.0
# Counter({'skipped-unranked team': 40200, 'incorrect': 11169, 'correct': 8565, 'tie': 232})
# accuracy: 0.43402249923989056
#
# Better player weight: 0.9
# Counter({'skipped-unranked team': 40200, 'incorrect': 11238, 'correct': 8571, 'tie': 157})
# accuracy: 0.43268211419051944
#
# Better player weight: 0.8
# Counter({'skipped-unranked team': 40200, 'incorrect': 11219, 'correct': 8585, 'tie': 162})
# accuracy: 0.43349828317511613
#
# Better player weight: 0.7
# Counter({'skipped-unranked team': 40200, 'incorrect': 11198, 'correct': 8607, 'tie': 161})
# accuracy: 0.4345872254481192
#
# Better player weight: 0.6
# Counter({'skipped-unranked team': 40200, 'incorrect': 11211, 'correct': 8593, 'tie': 162})
# accuracy: 0.43390224197131894

# %%
#p1440 points rankings with imputation adjusting weight balance
p1440_acc=[]
for i in [1-x/10 for x in range(5)]:
    results=predict_games(vball_all,p1440_point_rankings,p1440_dt_holder,max_is_higher=True,impute=True,better_player_weight=i,start_date=None)
    print('Better player weight:',i)
    print(results)
    print('accuracy:',results['correct']/(results['correct']+results['incorrect']))
    print('')
    p1440_acc.append(results['correct']/(results['correct']+results['incorrect']))

# Previous points with imputation
# Counter({'skipped-unranked team': 43118, 'incorrect': 9956, 'correct': 6838, 'tie': 254})
# accuracy: 0.40716922710491843
# Out:
# Better player weight: 1.0
# Counter({'skipped-unranked team': 43118, 'incorrect': 9862, 'correct': 6842, 'tie': 344})
# accuracy: 0.4096024904214559
#
# Better player weight: 0.9
# Counter({'skipped-unranked team': 43118, 'incorrect': 9929, 'correct': 6871, 'tie': 248})
# accuracy: 0.40898809523809526
#
# Better player weight: 0.8
# Counter({'skipped-unranked team': 43118, 'incorrect': 9931, 'correct': 6866, 'tie': 251})
# accuracy: 0.40876346966720245
#
# Better player weight: 0.7
# Counter({'skipped-unranked team': 43118, 'incorrect': 9945, 'correct': 6854, 'tie': 249})
# accuracy: 0.40800047621882257
#
# Better player weight: 0.6
# Counter({'skipped-unranked team': 43118, 'incorrect': 9930, 'correct': 6868, 'tie': 250})
# accuracy: 0.4088581974044529

# %% [markdown]
# ### Points Ranking Evaluation With Imputation (50/50 weight balance) (Using test data only)

# %%
#AAU points rankings with imputation
results=predict_games(vball_all,aau_point_rankings,aau_dt_holder,max_is_higher=True,impute=True,better_player_weight=.5,start_date=dt(2022,2,28))
print(results)
print('accuracy:',results['correct']/(results['correct']+results['incorrect']))

# Previous points with imputation
# Counter({'skipped-unranked team': 26882, 'incorrect': 17746, 'correct': 15314, 'tie': 224})
# accuracy: 0.4632183908045977
# Out:
# Counter({'skipped-unranked team': 5655, 'incorrect': 2009, 'correct': 1629, 'tie': 25})
# accuracy: 0.4477735019241341

# %%
#BVNE points rankings with imputation
results=predict_games(vball_all,bvne_point_rankings,bvne_dt_holder,max_is_higher=True,impute=True,better_player_weight=.5,start_date=dt(2022,2,28))
print(results)
print('accuracy:',results['correct']/(results['correct']+results['incorrect']))

# Previous points with imputation
# Counter({'skipped-unranked team': 40200, 'incorrect': 11215, 'correct': 8576, 'tie': 175})
# accuracy: 0.43332828053155475
# Out:
# Counter({'skipped-unranked team': 5878, 'incorrect': 2049, 'correct': 1362, 'tie': 29})
# accuracy: 0.3992963940193492

# %%
#p1440 points rankings with imputation
results=predict_games(vball_all,p1440_point_rankings,p1440_dt_holder,max_is_higher=True,impute=True,better_player_weight=.5,start_date=dt(2022,2,28))
print(results)
print('accuracy:',results['correct']/(results['correct']+results['incorrect']))

# Previous points with imputation
# Counter({'skipped-unranked team': 43118, 'incorrect': 9956, 'correct': 6838, 'tie': 254})
# accuracy: 0.40716922710491843
# Out:
# Counter({'skipped-unranked team': 6780, 'incorrect': 1544, 'correct': 960, 'tie': 34})
# accuracy: 0.38338658146964855
